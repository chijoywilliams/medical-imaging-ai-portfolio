# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import cv2
import tensorflow as tf
import torch

print("Medical Imaging AI Environment Initialized")
print("TensorFlow Version:", tf.__version__)
print("PyTorch Version:", torch.__version__)
# Out:
# Medical Imaging AI Environment Initialized
# TensorFlow Version: 2.21.0
# PyTorch Version: 2.12.0+cpu

# %%
research_focus = {
    "Project": "Medical Imaging AI",
    "Research Area": "Early Breast Cancer Detection",
    "Research Objectives": [
        "Medical image preprocessing",
        "MRI and mammogram visualization",
        "Image segmentation workflows",
        "Feature extraction",
        "Predictive diagnostic modeling",
        "Deep learning classification"
    ],
    "Technologies": [
        "TensorFlow",
        "PyTorch",
        "OpenCV",
        "Scikit-learn",
        "Python"
    ]
}

research_focus
# Out:
# {'Project': 'Medical Imaging AI',
#  'Research Area': 'Early Breast Cancer Detection',
#  'Research Objectives': ['Medical image preprocessing',
#   'MRI and mammogram visualization',
#   'Image segmentation workflows',
#   'Feature extraction',
#   'Predictive diagnostic modeling',
#   'Deep learning classification'],
#  'Technologies': ['TensorFlow', 'PyTorch', 'OpenCV', 'Scikit-learn', 'Python']}
